# %%
import pandas as pd
import json
import os
import ast
from pycaret.classification import *
from sklearn.preprocessing import MultiLabelBinarizer

# %%
#data = pd.read_csv('../data/50%_train_data.csv')
data = pd.read_csv('../data/train_data.csv')
print(data.iloc[0])
# Out:
# Unnamed: 0                                                    1287
# title                                                H. Squid Game
# TL                                                       2 seconds
# ML                                                   256 megabytes
# Input            The first line contains $$$2$$$ integer $$$n$$...
# Output           Print the minimum number of operations Mashtal...
# Note             Explanation for the first sample:  In the firs...
# Statement        After watching the new over-rated series Squid...
# contest                                                       1610
# index                                                            H
# tags             ['data structures', 'dfs and similar', 'greedy...
# rating                                                      3500.0
# sample-input     ['\n6 3\n1 1 1 4 4\n1 5\n3 4\n2 6\n', '\n5 3\n...
# sample-output                                  ['\n2\n', '\n-1\n']
# contest-name                            Codeforces Global Round 17
# Name: 0, dtype: object

# %%
def basic_preprocess(df):
    text_columns = ['title', 'Input', 'Output', 'Note', 'Statement']
    text_list_columns = ['sample-input', 'sample-output']
    df[text_columns] = df[text_columns].fillna('missing')
    df[text_list_columns] = df[text_list_columns].fillna('[]')

    df['title'] = df['title'].str.extract(r'^[A-Za-z0-9]+\.\s*(.+)')
    df['TL'] = df['TL'].str.extract(r'(\d+)').astype(int)
    df['ML'] = df['ML'].str.extract(r'(\d+)').astype(int)
    df['tags'] = df['tags'].apply(ast.literal_eval)
    df['sample-input'] = df['sample-input'].apply(ast.literal_eval).apply(lambda x: " ".join(x))
    df['sample-output'] = df['sample-output'].apply(ast.literal_eval).apply(lambda x: " ".join(x))

    df.drop(columns='Unnamed: 0', inplace=True)
    df.drop(columns='contest-name', inplace=True)
    return df

data = basic_preprocess(data)

# %%
print(data.iloc[0])
# Out:
# title                                                   Squid Game
# TL                                                               2
# ML                                                             256
# Input            The first line contains $$$2$$$ integer $$$n$$...
# Output           Print the minimum number of operations Mashtal...
# Note             Explanation for the first sample:  In the firs...
# Statement        After watching the new over-rated series Squid...
# contest                                                       1610
# index                                                            H
# tags             [data structures, dfs and similar, greedy, trees]
# rating                                                      3500.0
# sample-input     \n6 3\n1 1 1 4 4\n1 5\n3 4\n2 6\n \n5 3\n1 1 3...
# sample-output                                         \n2\n \n-1\n
# Name: 0, dtype: object

# %%
def tag_labeling(df):
    mlb = MultiLabelBinarizer()
    tags_binarized = mlb.fit_transform(df['tags'])
    tags_df = pd.DataFrame(tags_binarized, columns=mlb.classes_)
    df = pd.concat([df, tags_df], axis=1)
    df.drop(columns='tags', inplace=True)
    return tags_df, df

tags_df, data = tag_labeling(data)

# %%
print(data.iloc[0])
# Out:
# title                                                               Squid Game
# TL                                                                           2
# ML                                                                         256
# Input                        The first line contains $$$2$$$ integer $$$n$$...
# Output                       Print the minimum number of operations Mashtal...
# Note                         Explanation for the first sample:  In the firs...
# Statement                    After watching the new over-rated series Squid...
# contest                                                                   1610
# index                                                                        H
# rating                                                                  3500.0
# sample-input                 \n6 3\n1 1 1 4 4\n1 5\n3 4\n2 6\n \n5 3\n1 1 3...
# sample-output                                                     \n2\n \n-1\n
# *special                                                                     0
# 2-sat                                                                        0
# binary search                                                                0
# bitmasks                                                                     0
# brute force                                                                  0
# chinese remainder theorem                                                    0
# combinatorics                                                                0
# constructive algorithms                                                      0
# data structures                                                              1
# dfs and similar                                                              1
# divide and conquer                                                           0
# dp                                                                           0
# dsu                                                                          0
# expression parsing                                                           0
# fft                                                                          0
# flows                                                                        0
# games                                                                        0
# geometry                                                                     0
# graph matchings                                                              0
# graphs                                                                       0
# greedy                                                                       1
# hashing                                                                      0
# implementation                                                               0
# interactive                                                                  0
# math                                                                         0
# matrices                                                                     0
# meet-in-the-middle                                                           0
# number theory                                                                0
# probabilities                                                                0
# schedules                                                                    0
# shortest paths                                                               0
# sortings                                                                     0
# string suffix structures                                                     0
# strings                                                                      0
# ternary search                                                               0
# trees                                                                        1
# two pointers                                                                 0
# Name: 0, dtype: object

# %%
sub_data = data.iloc[:1000]
#sub_data = data
#for tag in tags_df.columns:
#for tag in ['binary search', 'dp', 'math', 'shortest paths']:
for tag in ['dp']:
    ignored_features = list(tags_df.columns.difference([tag]))
    exp = setup(data=sub_data, 
                target=tag, 
                text_features=['title', 'Input', 'Output', 'Note', 'Statement', 'sample-input', 'sample-output'],
                ignore_features=ignored_features,
                #fix_imbalance=True,
                session_id=123,
                #use_gpu=True
                )
    #model = compare_models()
    model = create_model('lightgbm')
    #final_model = finalize_model(model)
    evaluate_model(model)
# Out:
# <style type="text/css">
# #T_3d134_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_3d134">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3d134_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_3d134_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3d134_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3d134_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_3d134_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_3d134_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3d134_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_3d134_row1_col1" class="data row1 col1" >dp</td>
#     </tr>
#     <tr>
#       <th id="T_3d134_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3d134_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_3d134_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_3d134_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3d134_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_3d134_row3_col1" class="data row3 col1" >(1000, 49)</td>
#     </tr>
#     <tr>
#       <th id="T_3d134_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3d134_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_3d134_row4_col1" class="data row4 col1" >(1000, 16096)</td>
#     </tr>
#     <tr>
#       <th id="T_3d134_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3d134_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_3d134_row5_col1" class="data row5 col1" >(700, 16096)</td>
#     </tr>
#     <tr>
#       <th id="T_3d134_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3d134_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_3d134_row6_col1" class="data row6 col1" >(300, 16096)</td>
#     </tr>
#     <tr>
#       <th id="T_3d134_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3d134_row7_col0" class="data row7 col0" >Ignore features</td>
#       <td id="T_3d134_row7_col1" class="data row7 col1" >36</td>
#     </tr>
#     <tr>
#       <th id="T_3d134_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3d134_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_3d134_row8_col1" class="data row8 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_3d134_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3d134_row9_col0" class="data row9 col0" >Text features</td>
#       <td id="T_3d134_row9_col1" class="data row9 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_3d134_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_3d134_row10_col0" class="data row10 col0" >Categorical features</td>
#       <td id="T_3d134_row10_col1" class="data row10 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_3d134_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_3d134_row11_col0" class="data row11 col0" >Rows with missing values</td>
#       <td id="T_3d134_row11_col1" class="data row11 col1" >31.1%</td>
#     </tr>
#     <tr>
#       <th id="T_3d134_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_3d134_row12_col0" class="data row12 col0" >Preprocess</td>
#       <td id="T_3d134_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_3d134_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_3d134_row13_col0" class="data row13 col0" >Imputation type</td>
#       <td id="T_3d134_row13_col1" class="data row13 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_3d134_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_3d134_row14_col0" class="data row14 col0" >Numeric imputation</td>
#       <td id="T_3d134_row14_col1" class="data row14 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_3d134_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_3d134_row15_col0" class="data row15 col0" >Categorical imputation</td>
#       <td id="T_3d134_row15_col1" class="data row15 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_3d134_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_3d134_row16_col0" class="data row16 col0" >Text features embedding method</td>
#       <td id="T_3d134_row16_col1" class="data row16 col1" >tf-idf</td>
#     </tr>
#     <tr>
#       <th id="T_3d134_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_3d134_row17_col0" class="data row17 col0" >Maximum one-hot encoding</td>
#       <td id="T_3d134_row17_col1" class="data row17 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_3d134_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_3d134_row18_col0" class="data row18 col0" >Encoding method</td>
#       <td id="T_3d134_row18_col1" class="data row18 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_3d134_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_3d134_row19_col0" class="data row19 col0" >Fold Generator</td>
#       <td id="T_3d134_row19_col1" class="data row19 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_3d134_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_3d134_row20_col0" class="data row20 col0" >Fold Number</td>
#       <td id="T_3d134_row20_col1" class="data row20 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_3d134_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_3d134_row21_col0" class="data row21 col0" >CPU Jobs</td>
#       <td id="T_3d134_row21_col1" class="data row21 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_3d134_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_3d134_row22_col0" class="data row22 col0" >Use GPU</td>
#       <td id="T_3d134_row22_col1" class="data row22 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3d134_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_3d134_row23_col0" class="data row23 col0" >Log Experiment</td>
#       <td id="T_3d134_row23_col1" class="data row23 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3d134_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_3d134_row24_col0" class="data row24 col0" >Experiment Name</td>
#       <td id="T_3d134_row24_col1" class="data row24 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_3d134_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_3d134_row25_col0" class="data row25 col0" >USI</td>
#       <td id="T_3d134_row25_col1" class="data row25 col1" >171b</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_55f09_row10_col0, #T_55f09_row10_col1, #T_55f09_row10_col2, #T_55f09_row10_col3, #T_55f09_row10_col4, #T_55f09_row10_col5, #T_55f09_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_55f09">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_55f09_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_55f09_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_55f09_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_55f09_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_55f09_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_55f09_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_55f09_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_55f09_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_55f09_row0_col0" class="data row0 col0" >0.7714</td>
#       <td id="T_55f09_row0_col1" class="data row0 col1" >0.7997</td>
#       <td id="T_55f09_row0_col2" class="data row0 col2" >0.0714</td>
#       <td id="T_55f09_row0_col3" class="data row0 col3" >0.2500</td>
#       <td id="T_55f09_row0_col4" class="data row0 col4" >0.1111</td>
#       <td id="T_55f09_row0_col5" class="data row0 col5" >0.0244</td>
#       <td id="T_55f09_row0_col6" class="data row0 col6" >0.0308</td>
#     </tr>
#     <tr>
#       <th id="T_55f09_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_55f09_row1_col0" class="data row1 col0" >0.7714</td>
#       <td id="T_55f09_row1_col1" class="data row1 col1" >0.6122</td>
#       <td id="T_55f09_row1_col2" class="data row1 col2" >0.0714</td>
#       <td id="T_55f09_row1_col3" class="data row1 col3" >0.2500</td>
#       <td id="T_55f09_row1_col4" class="data row1 col4" >0.1111</td>
#       <td id="T_55f09_row1_col5" class="data row1 col5" >0.0244</td>
#       <td id="T_55f09_row1_col6" class="data row1 col6" >0.0308</td>
#     </tr>
#     <tr>
#       <th id="T_55f09_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_55f09_row2_col0" class="data row2 col0" >0.7857</td>
#       <td id="T_55f09_row2_col1" class="data row2 col1" >0.5574</td>
#       <td id="T_55f09_row2_col2" class="data row2 col2" >0.2143</td>
#       <td id="T_55f09_row2_col3" class="data row2 col3" >0.4286</td>
#       <td id="T_55f09_row2_col4" class="data row2 col4" >0.2857</td>
#       <td id="T_55f09_row2_col5" class="data row2 col5" >0.1758</td>
#       <td id="T_55f09_row2_col6" class="data row2 col6" >0.1905</td>
#     </tr>
#     <tr>
#       <th id="T_55f09_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_55f09_row3_col0" class="data row3 col0" >0.8000</td>
#       <td id="T_55f09_row3_col1" class="data row3 col1" >0.7615</td>
#       <td id="T_55f09_row3_col2" class="data row3 col2" >0.1429</td>
#       <td id="T_55f09_row3_col3" class="data row3 col3" >0.5000</td>
#       <td id="T_55f09_row3_col4" class="data row3 col4" >0.2222</td>
#       <td id="T_55f09_row3_col5" class="data row3 col5" >0.1463</td>
#       <td id="T_55f09_row3_col6" class="data row3 col6" >0.1846</td>
#     </tr>
#     <tr>
#       <th id="T_55f09_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_55f09_row4_col0" class="data row4 col0" >0.8143</td>
#       <td id="T_55f09_row4_col1" class="data row4 col1" >0.6594</td>
#       <td id="T_55f09_row4_col2" class="data row4 col2" >0.2143</td>
#       <td id="T_55f09_row4_col3" class="data row4 col3" >0.6000</td>
#       <td id="T_55f09_row4_col4" class="data row4 col4" >0.3158</td>
#       <td id="T_55f09_row4_col5" class="data row4 col5" >0.2353</td>
#       <td id="T_55f09_row4_col6" class="data row4 col6" >0.2774</td>
#     </tr>
#     <tr>
#       <th id="T_55f09_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_55f09_row5_col0" class="data row5 col0" >0.7571</td>
#       <td id="T_55f09_row5_col1" class="data row5 col1" >0.7927</td>
#       <td id="T_55f09_row5_col2" class="data row5 col2" >0.0667</td>
#       <td id="T_55f09_row5_col3" class="data row5 col3" >0.2500</td>
#       <td id="T_55f09_row5_col4" class="data row5 col4" >0.1053</td>
#       <td id="T_55f09_row5_col5" class="data row5 col5" >0.0165</td>
#       <td id="T_55f09_row5_col6" class="data row5 col6" >0.0214</td>
#     </tr>
#     <tr>
#       <th id="T_55f09_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_55f09_row6_col0" class="data row6 col0" >0.8000</td>
#       <td id="T_55f09_row6_col1" class="data row6 col1" >0.7103</td>
#       <td id="T_55f09_row6_col2" class="data row6 col2" >0.2667</td>
#       <td id="T_55f09_row6_col3" class="data row6 col3" >0.5714</td>
#       <td id="T_55f09_row6_col4" class="data row6 col4" >0.3636</td>
#       <td id="T_55f09_row6_col5" class="data row6 col5" >0.2632</td>
#       <td id="T_55f09_row6_col6" class="data row6 col6" >0.2901</td>
#     </tr>
#     <tr>
#       <th id="T_55f09_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_55f09_row7_col0" class="data row7 col0" >0.8286</td>
#       <td id="T_55f09_row7_col1" class="data row7 col1" >0.7952</td>
#       <td id="T_55f09_row7_col2" class="data row7 col2" >0.2000</td>
#       <td id="T_55f09_row7_col3" class="data row7 col3" >1.0000</td>
#       <td id="T_55f09_row7_col4" class="data row7 col4" >0.3333</td>
#       <td id="T_55f09_row7_col5" class="data row7 col5" >0.2821</td>
#       <td id="T_55f09_row7_col6" class="data row7 col6" >0.4052</td>
#     </tr>
#     <tr>
#       <th id="T_55f09_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_55f09_row8_col0" class="data row8 col0" >0.8143</td>
#       <td id="T_55f09_row8_col1" class="data row8 col1" >0.7964</td>
#       <td id="T_55f09_row8_col2" class="data row8 col2" >0.1333</td>
#       <td id="T_55f09_row8_col3" class="data row8 col3" >1.0000</td>
#       <td id="T_55f09_row8_col4" class="data row8 col4" >0.2353</td>
#       <td id="T_55f09_row8_col5" class="data row8 col5" >0.1947</td>
#       <td id="T_55f09_row8_col6" class="data row8 col6" >0.3284</td>
#     </tr>
#     <tr>
#       <th id="T_55f09_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_55f09_row9_col0" class="data row9 col0" >0.7857</td>
#       <td id="T_55f09_row9_col1" class="data row9 col1" >0.6715</td>
#       <td id="T_55f09_row9_col2" class="data row9 col2" >0.2000</td>
#       <td id="T_55f09_row9_col3" class="data row9 col3" >0.5000</td>
#       <td id="T_55f09_row9_col4" class="data row9 col4" >0.2857</td>
#       <td id="T_55f09_row9_col5" class="data row9 col5" >0.1860</td>
#       <td id="T_55f09_row9_col6" class="data row9 col6" >0.2132</td>
#     </tr>
#     <tr>
#       <th id="T_55f09_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_55f09_row10_col0" class="data row10 col0" >0.7929</td>
#       <td id="T_55f09_row10_col1" class="data row10 col1" >0.7156</td>
#       <td id="T_55f09_row10_col2" class="data row10 col2" >0.1581</td>
#       <td id="T_55f09_row10_col3" class="data row10 col3" >0.5350</td>
#       <td id="T_55f09_row10_col4" class="data row10 col4" >0.2369</td>
#       <td id="T_55f09_row10_col5" class="data row10 col5" >0.1549</td>
#       <td id="T_55f09_row10_col6" class="data row10 col6" >0.1972</td>
#     </tr>
#     <tr>
#       <th id="T_55f09_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_55f09_row11_col0" class="data row11 col0" >0.0214</td>
#       <td id="T_55f09_row11_col1" class="data row11 col1" >0.0830</td>
#       <td id="T_55f09_row11_col2" class="data row11 col2" >0.0677</td>
#       <td id="T_55f09_row11_col3" class="data row11 col3" >0.2637</td>
#       <td id="T_55f09_row11_col4
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
#test = pd.read_csv('../data/50%_test_data.csv')
test = pd.read_csv('../data/test_data.csv')
test = basic_preprocess(test)
tags_df, test = tag_labeling(test)

# %%
predictions = predict_model(model, data=test)
# Out:
# <style type="text/css">
# </style>
# <table id="T_2fc2d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2fc2d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_2fc2d_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_2fc2d_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_2fc2d_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_2fc2d_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_2fc2d_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_2fc2d_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_2fc2d_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2fc2d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2fc2d_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_2fc2d_row0_col1" class="data row0 col1" >0.7815</td>
#       <td id="T_2fc2d_row0_col2" class="data row0 col2" >0.7117</td>
#       <td id="T_2fc2d_row0_col3" class="data row0 col3" >0.1718</td>
#       <td id="T_2fc2d_row0_col4" class="data row0 col4" >0.5652</td>
#       <td id="T_2fc2d_row0_col5" class="data row0 col5" >0.2635</td>
#       <td id="T_2fc2d_row0_col6" class="data row0 col6" >0.1761</td>
#       <td id="T_2fc2d_row0_col7" class="data row0 col7" >0.2195</td>
#     </tr>
#   </tbody>
# </table>

# %%
y_pred = predictions['prediction_label']
test['Predicted'] = y_pred
wrong_predictions = test[test['dp'] != test['Predicted']]
wrong_predictions.head()
# Out:
#                               title  TL   ML  \
# 3          Last minute enhancements   1  256
# 4   The Minimum Number of Variables   1  256
# 9                        Staircases   2  256
# 10                    Tree Painting   2  256
# 16                        Isolation   3  256
#
#                                                 Input  \
# 3   The input consists of multiple test cases. The...
# 4   The first line contains integer n (1 ≤ n ≤ 23)...
# 9   The first line contains three integers $$$n$$$...
# 10  The first line contains an integer $$$n$$$ — t...
# 16  The first line contains two space-separated in...
#
#                                                Output  \
# 3   For each test case, you should output a single...
# 4   In a single line print a single number — the m...
# 9   Print $$$q$$$ integers — the $$$i$$$-th value ...
# 10  Print one integer — the maximum number of poin...
# 16  The first and only line contains the number of...
#
#                                                  Note  \
# 3   In the first test case, Euterpe can increase t...
# 4   In the first sample, you can use two variables...
# 9                                             missing
# 10  The first example tree is shown in the problem...
# 16  In the first sample, the three possible divisi...
#
#                                             Statement  contest index  rating  \
# 3   Athenaeus has just finished creating his lates...     1466     B   750.0
# 4   You've got a positive integer sequence a1, a2,...      279     D  2000.0
# 9   You are given a matrix, consisting of $$$n$$$ ...     1598     E     NaN
# 10  You are given a tree (an undirected connected ...     1187     E     NaN
# 16  Find the number of ways to divide an array $$$...     1129     D  2250.0
#
#     ... probabilities schedules  shortest paths  sortings  \
# 3   ...             0         0               0         0
# 4   ...             0         0               0         0
# 9   ...             0         0               0         0
# 10  ...             0         0               0         0
# 16  ...             0         0               0         0
#
#     string suffix structures  strings  ternary search  trees  two pointers  \
# 3                          0        0               0      0             0
# 4                          0        0               0      0             0
# 9                          0        0               0      0             0
# 10                         0        0               0      1             0
# 16                         0        0               0      0             0
#
#     Predicted
# 3           0
# 4           0
# 9           0
# 10          0
# 16          0
#
# [5 rows x 50 columns]
